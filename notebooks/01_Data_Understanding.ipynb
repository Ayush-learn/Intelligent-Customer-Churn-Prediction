# %%
import pandas as pd
import numpy as np

# %%
 df = pd.read_csv("../data/raw/Telco-Customer-Churn.csv")

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.head()
# Out:
#    customerID  gender  SeniorCitizen Partner Dependents  tenure PhoneService  \
# 0  7590-VHVEG  Female              0     Yes         No       1           No
# 1  5575-GNVDE    Male              0      No         No      34          Yes
# 2  3668-QPYBK    Male              0      No         No       2          Yes
# 3  7795-CFOCW    Male              0      No         No      45           No
# 4  9237-HQITU  Female              0      No         No       2          Yes
#
#       MultipleLines InternetService OnlineSecurity  ... DeviceProtection  \
# 0  No phone service             DSL             No  ...               No
# 1                No             DSL            Yes  ...              Yes
# 2                No             DSL            Yes  ...               No
# 3  No phone service             DSL            Yes  ...              Yes
# 4                No     Fiber optic             No  ...               No
#
# ...

# %%
df.tail()
# Out:
#       customerID  gender  SeniorCitizen Partner Dependents  tenure  \
# 7038  6840-RESVB    Male              0     Yes        Yes      24
# 7039  2234-XADUH  Female              0     Yes        Yes      72
# 7040  4801-JZAZL  Female              0     Yes        Yes      11
# 7041  8361-LTMKD    Male              1     Yes         No       4
# 7042  3186-AJIEK    Male              0      No         No      66
#
#      PhoneService     MultipleLines InternetService OnlineSecurity  ...  \
# 7038          Yes               Yes             DSL            Yes  ...
# 7039          Yes               Yes     Fiber optic             No  ...
# 7040           No  No phone service             DSL            Yes  ...
# 7041          Yes               Yes     Fiber optic             No  ...
# 7042          Yes                No     Fiber optic            Yes  ...
#
#      DeviceProtection TechSupport StreamingTV StreamingMovies        Contract  \
# ...

# %%
df.shape
# Out:
# (7043, 21)

# %%
df.columns
# Out:
# Index(['customerID', 'gender', 'SeniorCitizen', 'Partner', 'Dependents',
#        'tenure', 'PhoneService', 'MultipleLines', 'InternetService',
#        'OnlineSecurity', 'OnlineBackup', 'DeviceProtection', 'TechSupport',
#        'StreamingTV', 'StreamingMovies', 'Contract', 'PaperlessBilling',
#        'PaymentMethod', 'MonthlyCharges', 'TotalCharges', 'Churn'],
#       dtype='object')

# %%
df.dtypes
# Out:
# customerID           object
# gender               object
# SeniorCitizen         int64
# Partner              object
# Dependents           object
# tenure                int64
# PhoneService         object
# MultipleLines        object
# InternetService      object
# OnlineSecurity       object
# OnlineBackup         object
# DeviceProtection     object
# TechSupport          object
# StreamingTV          object
# StreamingMovies      object
# Contract             object
# PaperlessBilling     object
# PaymentMethod        object
# MonthlyCharges      float64
# TotalCharges         object
# Churn                object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 21 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   customerID        7043 non-null   object
#  1   gender            7043 non-null   object
#  2   SeniorCitizen     7043 non-null   int64
#  3   Partner           7043 non-null   object
#  4   Dependents        7043 non-null   object
#  5   tenure            7043 non-null   int64
#  6   PhoneService      7043 non-null   object
#  7   MultipleLines     7043 non-null   object
#  8   InternetService   7043 non-null   object
#  9   OnlineSecurity    7043 non-null   object
#  10  OnlineBackup      7043 non-null   object
#  11  DeviceProtection  7043 non-null   object
#  12  TechSupport       7043 non-null   object
#  13  StreamingTV       7043 non-null   object
#  14  StreamingMovies   7043 non-null   object
#  15  Contract          7043 non-null   object
# ...

# %%
df.describe()
# Out:
#        SeniorCitizen       tenure  MonthlyCharges
# count    7043.000000  7043.000000     7043.000000
# mean        0.162147    32.371149       64.761692
# std         0.368612    24.559481       30.090047
# min         0.000000     0.000000       18.250000
# 25%         0.000000     9.000000       35.500000
# 50%         0.000000    29.000000       70.350000
# 75%         0.000000    55.000000       89.850000
# max         1.000000    72.000000      118.750000

# %%
df.describe(include='object')
# Out:
#         customerID gender Partner Dependents PhoneService MultipleLines  \
# count         7043   7043    7043       7043         7043          7043
# unique        7043      2       2          2            2             3
# top     7590-VHVEG   Male      No         No          Yes            No
# freq             1   3555    3641       4933         6361          3390
#
#        InternetService OnlineSecurity OnlineBackup DeviceProtection  \
# count             7043           7043         7043             7043
# unique               3              3            3                3
# top        Fiber optic             No           No               No
# freq              3096           3498         3088             3095
#
#        TechSupport StreamingTV StreamingMovies        Contract  \
# count         7043        7043            7043            7043
# unique           3           3               3               3
# top             No          No              No  Month-to-month
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["Contract"].unique()
# Out:
# array(['Month-to-month', 'One year', 'Two year'], dtype=object)

# %%
df["Churn"].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
df["Churn"].value_counts()
# Out:
# Churn
# No     5174
# Yes    1869
# Name: count, dtype: int64

# %%
df["Churn"].value_counts(normalize=True)
# Out:
# Churn
# No     0.73463
# Yes    0.26537
# Name: proportion, dtype: float64

# %%
df.memory_usage(deep=True)
# Out:
# Index                  132
# customerID          415537
# gender              380255
# SeniorCitizen        56344
# Partner             362595
# Dependents          361303
# tenure               56344
# PhoneService        365554
# MultipleLines       371712
# InternetService     389478
# OnlineSecurity      387154
# OnlineBackup        387564
# DeviceProtection    387557
# TechSupport         387179
# StreamingTV         387842
# StreamingMovies     387867
# Contract            424701
# PaperlessBilling    363364
# PaymentMethod       475897
# MonthlyCharges       56344
# TotalCharges        386502
# Churn               361062
# dtype: int64

# %%
📋 Data Understanding Observations
Observation 1: Dataset Size
The dataset contains 7,043 customer records and 21 columns.
Each row represents one unique customer, while each column represents a feature describing customer demographics, services, billing information, or churn status.
Observation 2: Dataset Structure
The dataset consists of:
18 categorical (object) columns
2 integer columns
1 floating-point column
Since most features are categorical, encoding techniques will be required before training machine learning models.
Observation 3: Missing Values
Based on df.info(), every column contains 7,043 non-null values, indicating that there are no explicit missing (NaN) values in the dataset.
However, the TotalCharges column is stored as an object instead of a numerical datatype, suggesting that it may contain blank spaces or invalid values that require further investigation during data cleaning.

Professional Note: Missing values are not always represented as NaN; sometimes they appear as empty strings or spaces.

Observation 4: Numerical Features

The dataset contains only three numerical features:

SeniorCitizen
tenure
MonthlyCharges

From the statistical summary:

Average customer tenure is approximately 32 months.
Monthly charges range from ₹18.25 to ₹118.75 (dataset currency).
Tenure ranges from 0 to 72 months, indicating customers with both very recent and long-term subscriptions.
Observation 5: Categorical Features

Most variables are categorical and describe customer characteristics such as:

Gender
Internet Service
Contract Type
Payment Method
Online Security
Streaming Services

These variables are expected to play a significant role in predicting customer churn.

Observation 6: Identifier Column

The customerID column contains 7,043 unique values, meaning every customer has a unique identifier.

Since customer IDs do not provide predictive information, this column will be removed before model training.

Observation 7: Target Variable

The target variable is Churn, which has two classes:

Yes
No

This confirms that the problem is a Binary Classification problem.

Observation 8: Class Distribution

The class distribution is:

No (Retained Customers): 73.46%
Yes (Churned Customers): 26.54%

This indicates that the dataset is moderately imbalanced, as the majority of customers did not churn.

During model development, evaluation metrics such as Precision, Recall, F1-score, and ROC-AUC will be more informative than relying solely on Accuracy.

Observation 9: Data Types

Most columns are stored as object datatype.

These columns cannot be directly used by machine learning algorithms and will require appropriate encoding techniques during preprocessing.

Observation 10: Initial Business Insight

Even before performing Exploratory Data Analysis (EDA), several features appear likely to influence customer churn, including:

Contract Type
Internet Service
Monthly Charges
Tenure
Payment Method

These variables will be analyzed further to understand their relationship with customer churn.
